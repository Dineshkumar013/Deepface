# %% [markdown]
# <a href="https://colab.research.google.com/github/Dineshkumar013/Deepface/blob/main/deepface.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install deepface
# Out:
# ...
#      |████████████████████████████████| 63 kB 806 kB/s
# ...
#      |████████████████████████████████| 2.3 MB 26.7 MB/s
# ...
#      |████████████████████████████████| 462 kB 40.1 MB/s
# ...

# %%
from deepface import DeepFace
import cv2 
import matplotlib.pyplot as plt
# Out:
# Directory  /root /.deepface created
# Directory  /root /.deepface/weights created

# %%
img=cv2.imread("/content/passport size pic dinesh.jpeg")
plt.imshow(img[:,:,::-1])
plt.show()

# %%
result=DeepFace.analyze(img,actions=['emotion'])
# Out:
# Downloading...
# From: https://github.com/serengil/deepface_models/releases/download/v1.0/facial_expression_model_weights.h5
# To: /root/.deepface/weights/facial_expression_model_weights.h5
# facial_expression_model_weights.h5 will be downloaded...
# 100%|██████████| 5.98M/5.98M [00:00<00:00, 80.1MB/s]

# %%
print(result["dominant_emotion"])
# Out:
# neutral

# %%
while True:
	ret, frame = video.read()
	faces = DeepFace.detectMultiScale(frame, 1.3, 5)
	for x, y, w, h in faces:
		count = count + 1
		cv2.rectangle(frame, (x, y), (x+w, y+h), (0, 0, 255), 3)

		cv2.putText(frame, "No Mask", (x+15 , y-15), cv2.FONT_HERSHEY_COMPLEX_SMALL, 0.75, (0, 0, 255), 1)

	cv2.imshow("Frame", frame)
	key = cv2.waitKey(1) & 0xFF
	if key == ord("q"):
		break
video.release()
cv2.destroyAllWindows()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-7-31a70370d7cd> in <module>()
#       1 while True:
# ----> 2         ret, frame = video.read()
#       3         faces = DeepFace.detectMultiScale(frame, 1.3, 5)
#       4         for x, y, w, h in faces:
#       5                 count = count + 1
#
# NameError: name 'video' is not defined
